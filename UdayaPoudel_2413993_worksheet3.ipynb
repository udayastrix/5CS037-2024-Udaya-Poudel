# %% [markdown]
# # Udaya Poudel 2413993 // Workshop 3

# %% [markdown]
# Task 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
titanic=pd.read_csv("/Users/udaya/Documents/machine learning/Titanic-Dataset.csv")
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#1 creating a dataframe called fare with fare values
Fare = titanic[['Fare']]
Fare.head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
# creating a dataframe called class_age that holds Pclass and Age data
class_age = titanic[['Pclass', 'Age']]
class_age.head()
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
# creating a dataframe called survived_gender Survived and Sex
survived_gender = titanic[['Survived','Sex']]
survived_gender.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %% [markdown]
# # Problem - 2 - Subsetting:

# %%
fare_gt_100 = titanic[titanic['Fare'] > 100]
fare_gt_100.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 27                   Fortune, Mr. Charles Alexander    male  19.0      3
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                       Fortune, Miss. Mabel Helen  female  23.0      3
# 118                        Baxter, Mr. Quigg Edmond    male  24.0      0
# 195                            Lurette, Miss. Elise  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 27       2     19950  263.0000  C23 C25 C27        S
# 31       0  PC 17569  146.5208          B78        C
# 88       2     19950  263.0000  C23 C25 C27        S
# 118      1  PC 17558  247.5208      B58 B60        C
# ...

# %%
first_class=titanic[titanic['Pclass']==1]
first_class.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 23      0    113788  35.5000    A6        S

# %%
female_under_18=titanic[(titanic['Age']<18) & (titanic['Sex']=="female")]
female_under_18.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22           23         1       3           McGowan, Miss. Anna "Annie"
# 24           25         0       3         Palsson, Miss. Torborg Danira
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 14  female  14.0      0      0   350406   7.8542   NaN        S
# 22  female  15.0      0      0   330923   8.0292   NaN        Q
# 24  female   8.0      3      1   349909  21.0750   NaN        S

# %%
embarked_c_or_s=titanic[(titanic['Embarked']=="C") | (titanic['Embarked']=="S")]
embarked_c_or_s.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
first_second_class=titanic[(titanic['Pclass'].isin([1,2]))]
first_second_class.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S

# %% [markdown]
# # 3.2 Exploratory Data Analysis Practice Exercise - 1.

# %%
# Handling missing values
titanic['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
median_df=titanic['Age'].median()
titanic['Age'] = titanic['Age'].fillna(median_df)
titanic['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
#1
titanic['fare_per_year']=titanic['Fare'] / titanic['Age']
titanic['fare_per_year']
# Out:
# 0      0.329545
# 1      1.875876
# 2      0.304808
# 3      1.517143
# 4      0.230000
#          ...
# 886    0.481481
# 887    1.578947
# 888    0.837500
# 889    1.153846
# 890    0.242188
# Name: fare_per_year, Length: 891, dtype: float64

# %%
high_fare_age=titanic[titanic['fare_per_year'] > 5]
high_fare_age.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 7             8         0       3
# 16           17         0       3
# 27           28         0       1
# 31           32         1       1
# 43           44         1       2
#
#                                               Name     Sex   Age  SibSp  \
# 7                   Palsson, Master. Gosta Leonard    male   2.0      3
# 16                            Rice, Master. Eugene    male   2.0      4
# 27                  Fortune, Mr. Charles Alexander    male  19.0      3
# 31  Spencer, Mrs. William Augustus (Marie Eugenie)  female  28.0      1
# 43        Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
#
#     Parch         Ticket      Fare        Cabin Embarked  fare_per_year
# 7       1         349909   21.0750          NaN        S      10.537500
# 16      1         382652   29.1250          NaN        Q      14.562500
# 27      2          19950  263.0000  C23 C25 C27        S      13.842105
# ...

# %%
high_fare_age_srt =high_fare_age.sort_values(by='fare_per_year', ascending=False)
high_fare_age_srt
# Out:
#      PassengerId  Survived  Pclass  \
# 305          306         1       1
# 297          298         0       1
# 386          387         0       3
# 164          165         0       3
# 183          184         1       2
# ..           ...       ...     ...
# 348          349         1       3
# 31            32         1       1
# 205          206         0       3
# 813          814         0       3
# 480          481         0       3
#
#                                                Name     Sex    Age  SibSp  \
# 305                  Allison, Master. Hudson Trevor    male   0.92      1
# 297                    Allison, Miss. Helen Loraine  female   2.00      1
# 386                 Goodwin, Master. Sidney Leonard    male   1.00      5
# 164                    Panula, Master. Eino Viljami    male   1.00      4
# 183                       Becker, Master. Richard F    male   1.00      2
# ..                                              ...     ...    ...    ...
# ...

# %%
result = high_fare_age_srt[['Name', 'fare_per_year']]

# %%
result.head()
# Out:
#                                 Name  fare_per_year
# 305   Allison, Master. Hudson Trevor     164.728261
# 297     Allison, Miss. Helen Loraine      75.775000
# 386  Goodwin, Master. Sidney Leonard      46.900000
# 164     Panula, Master. Eino Viljami      39.687500
# 183        Becker, Master. Richard F      39.000000

# %%
titanic['fare_per_class']=titanic['Fare'] / titanic['Pclass']
titanic['fare_per_class'].head()
# Out:
# 0     2.416667
# 1    71.283300
# 2     2.641667
# 3    53.100000
# 4     2.683333
# Name: fare_per_class, dtype: float64

# %%
adult_males=titanic[(titanic['Age']<18) & (titanic['Sex']=="male")]
adult_males.head()
# Out:
#     PassengerId  Survived  Pclass                                Name   Sex  \
# 7             8         0       3      Palsson, Master. Gosta Leonard  male
# 16           17         0       3                Rice, Master. Eugene  male
# 50           51         0       3          Panula, Master. Juha Niilo  male
# 59           60         0       3  Goodwin, Master. William Frederick  male
# 63           64         0       3               Skoog, Master. Harald  male
#
#      Age  SibSp  Parch   Ticket     Fare Cabin Embarked  fare_per_year  \
# 7    2.0      3      1   349909  21.0750   NaN        S      10.537500
# 16   2.0      4      1   382652  29.1250   NaN        Q      14.562500
# 50   7.0      4      1  3101295  39.6875   NaN        S       5.669643
# 59  11.0      5      2  CA 2144  46.9000   NaN        S       4.263636
# 63   4.0      3      2   347088  27.9000   NaN        S       6.975000
#
#     fare_per_class
# 7         7.025000
# 16        9.708333
# 50       13.229167
# ...

# %%
adult_males_srt=adult_males.sort_values(by='fare_per_class' ,ascending=False)
adult_males_srt.head()
# Out:
#      PassengerId  Survived  Pclass                                 Name   Sex  \
# 305          306         1       1       Allison, Master. Hudson Trevor  male
# 802          803         1       1  Carter, Master. William Thornton II  male
# 550          551         1       1          Thayer, Mr. John Borland Jr  male
# 445          446         1       1            Dodge, Master. Washington  male
# 183          184         1       2            Becker, Master. Richard F  male
#
#        Age  SibSp  Parch  Ticket      Fare    Cabin Embarked  fare_per_year  \
# 305   0.92      1      2  113781  151.5500  C22 C26        S     164.728261
# 802  11.00      1      2  113760  120.0000  B96 B98        S      10.909091
# 550  17.00      0      2   17421  110.8833      C70        C       6.522547
# 445   4.00      0      2   33638   81.8583      A34        S      20.464575
# 183   1.00      2      1  230136   39.0000       F4        S      39.000000
#
#      fare_per_class
# ...

# %% [raw]
# result=titanic[adu

# %%
result2=adult_males_srt[['Name' , 'Age', 'fare_per_class']]
result2.head()
# Out:
#                                     Name    Age  fare_per_class
# 305       Allison, Master. Hudson Trevor   0.92        151.5500
# 802  Carter, Master. William Thornton II  11.00        120.0000
# 550          Thayer, Mr. John Borland Jr  17.00        110.8833
# 445            Dodge, Master. Washington   4.00         81.8583
# 183            Becker, Master. Richard F   1.00         19.5000

# %% [markdown]
# # 3.3 Exploratory Data Analysis with Group-by Method Practice Exercise:

# %%
Total_Fare=titanic['Fare'].sum()
Total_Fare
# Out:
# np.float64(28693.9493)

# %%
first_class1=titanic[titanic['Pclass']==1]
class1=first_class1['Fare'].sum()
class1
# Out:
# np.float64(18177.4125)

# %%
first_class2=titanic[titanic['Pclass']==2]
class2=first_class2['Fare'].sum()
class2
# Out:
# np.float64(3801.8417)

# %%
first_class3=titanic[titanic['Pclass']==3]
class3=first_class3['Fare'].sum()
class3
# Out:
# np.float64(6714.6951)

# %%
total_fare = class1 + class2 + class3
total_fare
# Out:
# np.float64(28693.9493)

# %%
first_class_proportion = (class1 / total_fare) * 100
first_class_proportion
# Out:
# np.float64(63.349287718996564)

# %%
first_class_proportion = (class2 / total_fare) * 100
first_class_proportion
# Out:
# np.float64(13.24962855496507)

# %%
first_class_proportion = (class3 / total_fare) * 100
first_class_proportion
# Out:
# np.float64(23.401083726038365)

# %%
titanic['age_group']=''
titanic.loc[titanic['Age']<18, 'age_group'] = 'child'
titanic.loc[titanic['Age']>18, 'age_group'] = 'adult'
titanic.loc[titanic['Age']>65, 'age_group'] = 'senior'
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# ...

# %%
children = titanic[titanic['age_group'] == 'child']
children.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 7             8         0       3        Palsson, Master. Gosta Leonard
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16           17         0       3                  Rice, Master. Eugene
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked  \
# 7     male   2.0      3      1   349909  21.0750   NaN        S
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 14  female  14.0      0      0   350406   7.8542   NaN        S
# 16    male   2.0      4      1   382652  29.1250   NaN        Q
#
#     fare_per_year  fare_per_class age_group
# 7       10.537500        7.025000     child
# 9        2.147914       15.035400     child
# ...

# %%
total_passengers=titanic['PassengerId'].count()
total_passengers
# Out:
# np.int64(891)

# %%
age_group_value=titanic['age_group'].value_counts()
age_group_value.head()
# Out:
# age_group
# adult     744
# child     113
#            26
# senior      8
# Name: count, dtype: int64

# %%
total_passenger=len(titanic)

# %%
print(age_group_value['adult']/total_passengers*100)
# Out:
# 83.5016835016835

# %%
print(age_group_value['child']/total_passengers*100)
# Out:
# 12.682379349046016

# %%
print(age_group_value['senior']/total_passengers*100)
# Out:
# 0.8978675645342313
